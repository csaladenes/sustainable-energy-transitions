# %% [markdown]
# population

# %%
#Routines for scraping and downloading data from http://esa.un.org/unpd/wpp/unpp/panel_indicators.htm
#Source: http://schoolofdata.org/2014/09/12/easy-access-to-world-bank-and-un-development-data-from-ipython-notebooks/

import requests
from bs4 import BeautifulSoup

from io import StringIO
import pandas as pd

def getFormSelectVals(soup,name):
    #Parse out options from an HTML select list
    
    tmp={}
    items=soup.find('select',{'name':name})
    for o in items.findAll('option'):
        #print(o.attrs['value'],o.text.strip())
        tmp[o.text.strip()]=o.attrs['value']
    return tmp


def getUNPopDivIndicators():
    #Grab the UN Population Division indicators page and parse out form values
    
    url='http://esa.un.org/unpd/wpp/unpp/panel_indicators.htm'
    page = requests.get(url)
    
    soup=BeautifulSoup(page.content)
    
    unpop={}
    unpop['vars']=getFormSelectVals(soup,'Variable')
    unpop['countries']=getFormSelectVals(soup,'Location')
    unpop['variants']=getFormSelectVals(soup,'Varient')
      
    return unpop

def getUNPopDivData(dfi,country,indicator,variant='Medium variant',startyear=1950,endyear=2100):
    #Download selected data from the UN Population Division indicators page and return it as a pandas dataframe
    
    if not isinstance(country,list): country= [country] 
    if not isinstance(indicator,list): indicator= [indicator]
    
    #Limited to five options - use the first 5
    #For each item, look up the name from the scraped form elements and find what code number to use.
    locations= [dfi['countries'][x] for x in country[:5]]
    variables= [dfi['vars'][x] for x in indicator[:5]]
    
    varient=dfi['variants'][variant]
    
    data=[('Panel',2),('Varient',varient),('StartYear',startyear),('EndYear',endyear),('DoWhat','Download as .CSV File')]
    
    #If we request multiple locations or variables, the form repeats the 'Location' or 'Variable' attribute name
    #This means we can't use a Python dict to represent the arguments - instead we create a list of tuples
    for l in locations: data.append(('Location',l))
    for v in variables: data.append(('Variable',v))
    
    url='http://esa.un.org/unpd/wpp/unpp/p2k0data_script.asp'

    response = requests.post(url,data=data)
    
    #The data is returned as a string - we use StringIO to make it look like a file stream so pd.read_csv() can read it
    #The last two lines of the returned data are an empty line and a metadata line - so let's ignore them.
    #skipfooter currently only works with the python engine - so let's declare that to prevent a warning
    
    #old version with skipfooter, unicode characters represent a problem
    #df=pd.read_csv(StringIO(response.text), skipfooter=2, engine='python', encoding='latin-1')
    
    #new version, unicode OK (you're welcome Côte d'Ivoire)
    df=pd.read_csv(StringIO(response.text))
    df.ix[0:len(df.index)-3]
    
    return df

# %%
#Helper routines for working with the data
def search(d, substr):
    #Partial string match search within dict key names
    #via http://stackoverflow.com/a/10796050/454773
    
    result = []
    for key in d:
        if substr.lower() in key.lower():
            result.append((key, d[key])) 

    return result

# %% [markdown]
# So that's the code... now how do we use it?
#
# The first thing we need to do is see what indicators are available:

# %%
#Get indicators
dfi=getUNPopDivIndicators()

#Preview indicators
dfi['vars']
# Out:
# {u'Age-specific fertility rates': '-5;',
#  u'Births': '51;',
#  u'Births by age group of mother': '-6;',
#  u'Crude birth rate': '53;',
#  u'Crude death rate': '65;',
#  u'Deaths by sex': ':62,63,64;',
#  u'Dependency ratios': ':42,43,44;',
#  u'Infant mortality rate': ':75,76,77;',
#  u'Life expectancy at birth': ':66,67,68;',
#  u'Median age': '41;',
#  u'Net migration': '84;',
#  u'Net migration rate': '85;',
#  u'Net reproduction rate': '48;',
#  u'Population 60+': ':22,33;',
#  u'Population 65+': ':23,34;',
#  u'Population 80+': ':24,35;',
#  u'Population aged 0-14': ':86,101;',
#  u'Population aged 0-4': ':19,30;',
#  u'Population aged 15-24': ':21,32;',
#  u'Population aged 15-59': ':87,102;',
#  u'Population aged 15-64': ':88,103;',
#  u'Population aged 5-14': ':20,31;',
#  u'Population by five-year age group and sex': '-2;',
#  u'Population by sex (annual)': '-1;',
#  u'Population change': '46;',
#  u'Population growth rate': '47;',
#  u'Population sex ratio': '13;',
#  u'Sex ratio at birth': '52;',
#  u'Total fertility': '54;',
#  u'Under-five mortality': ':78,79,80;',
#  u'Women aged 15-49': ':25,36;'}

# %% [markdown]
# We can also search within indicators to find their proper names.

# %%
#Example search within indicators
search(dfi['vars'],'pop')
# Out:
# [(u'Population sex ratio', '13;'),
#  (u'Population 60+', ':22,33;'),
#  (u'Population 65+', ':23,34;'),
#  (u'Population 80+', ':24,35;'),
#  (u'Population growth rate', '47;'),
#  (u'Population aged 5-14', ':20,31;'),
#  (u'Population aged 15-64', ':88,103;'),
#  (u'Population aged 15-24', ':21,32;'),
#  (u'Population aged 0-14', ':86,101;'),
#  (u'Population by five-year age group and sex', '-2;'),
#  (u'Population aged 15-59', ':87,102;'),
#  (u'Population aged 0-4', ':19,30;'),
#  (u'Population by sex (annual)', '-1;'),
#  (u'Population change', '46;')]

# %% [markdown]
# The following shows us what prediction variants are supported.

# %%
#Show variants of predictions
dfi['variants']
# Out:
# {u'Constant-fertility variant': '5',
#  u'High variant': '3',
#  u'Low variant': '4',
#  u'Medium variant': '2'}

# %% [markdown]
# We search for countries by name - but we need to make sure we pass the name in correctly. So search to find out...

# %%
#Example search within country names
search(dfi['countries'],'united')
# Out:
# [(u'United States of America', '840'),
#  (u'United Republic of Tanzania', '834'),
#  (u'United States Virgin Islands', '850'),
#  (u'United Arab Emirates', '784'),
#  (u'United Kingdom', '826')]

# %% [markdown]
# Once we know what we want to ask for, we can make a data request.

# %%
#Let's run a test query
pop=getUNPopDivData(dfi,['World'],
                      ['Population by sex (annual)'])
pop=pop.query('Sex=="Total"').drop(['Sex','Variable','Variant'],axis=1).set_index(['Country','Year'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
pop.loc['World'].plot()

# %% [markdown]
# UN POP Stats API can take calls only for max 5 countries at a time. Let's split the country list into batches of 5 and do the calls.

# %%
def split(arr, size):
     arrs = []
     while len(arr) > size:
         pice = arr[:size]
         arrs.append(pice)
         arr   = arr[size:]
     arrs.append(arr)
     return arrs

# %%
#Make all calls - could take up to 5 minutes based on your internet connection and processor speed
n = len(split(list(dfi['countries']),5))
pop = pd.DataFrame()
for i in range(n):
    print round((i+1)/float(n),2)
    pop2=getUNPopDivData(dfi,split(list(dfi['countries']),5)[i],
                          ['Population by sex (annual)'])
    pop2=pop2.query('Sex=="Total"').drop(['Sex','Variable','Variant'],axis=1).set_index(['Country','Year'])
    pop=pd.concat([pop,pop2])
    
#save to file to avoid running again
file('pop.json','w').write(pop.to_csv())

# %%
file('pop.csv','w').write(pop.to_csv())

# %%
pop.loc['World'].plot()

# %% [markdown]
# #Direct Access

# %% [markdown]
# You can acess my datafile directly:

# %%
pop2=pd.read_csv('https://dl.dropboxusercontent.com/u/333992592/Set/db/pop.csv').set_index(['Country','Year'])
pop2
# Out:
#               Value
# Country Year
# Canada  1950  13737
#         1951  14100
#         1952  14482
#         1953  14882
#         1954  15300
#         1955  15734
#         1956  16178
#         1957  16625
#         1958  17068
#         1959  17499
#         1960  17909
#         1961  18295
#         1962  18658
#         1963  19004
#         1964  19345
#         1965  19689
#         1966  20036
#         1967  20384
#         1968  20734
#         1969  21084
#         1970  21434
#         1971  21786
#         1972  22137
#         1973  22484
#         1974  22819
#         1975  23136
#         1976  23435
#         1977  23719
#         1978  23990
#         1979  24253
# ...             ...
# Comoros 2071   1991
#         2072   2013
#         2073   2035
#         2074   2057
#         2075   2078
#         2076   2100
#         2077   2121
#         2078   2141
#         2079   2162
#         2080   2183
#         2081   2203
#         2082   2223
#         2083   2243
#         2084   2262
#         2085   2281
#         2086   2300
#         2087   2319
#         2088   2337
#         2089   2356
#         2090   2374
#         2091   2391
#         2092   2409
#         2093   2426
#         2094   2443
#         2095   2459
#         2096   2475
#         2097   2491
#         2098   2507
#         2099   2523
#         2100   2538
#
# [35636 rows x 1 columns]

# %% [markdown]
# ## Upload to Quandl (optional)

# %% [markdown]
# import Quandl

# %%
import Quandl as qd

# %% [markdown]
# First load the population data from the csv file generated with the other code

# %%
pop=pd.read_csv('https://dl.dropboxusercontent.com/u/333992592/Set/db/pop.csv')
#use your path if you wish and you processed the data above
pop['Year']=pop['Year'].astype(int).astype(str)
pop['Year']=pd.to_datetime(pop['Year'])
pop=pop.set_index(['Year','Country'],drop=True).unstack()['Value']

# %% [markdown]
# country and region name converters

# %%
countries=pd.read_html('http://www.nationsonline.org/oneworld/country_code_list.htm',header=0,infer_types=False)[4]
countries.drop(countries[[0]],axis=1,inplace=True)
countries.columns=['NAME','ISO2','ISO3','ISONUM']
countries.set_index('NAME',drop=True,inplace=True)
countries.head()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\pandas\io\html.py:841: FutureWarning: infer_types will have no effect in 0.14
#   warnings.warn("infer_types will have no effect in 0.14", FutureWarning)
#                ISO2 ISO3 ISONUM
# NAME
# Afghanistan      AF  AFG      4
# Aland Islands    AX  ALA    248
# Albania          AL  ALB      8
# Algeria          DZ  DZA     12
# American Samoa   AS  ASM     16

# %%
def cnc(country):
    #country name converter
    
    if country=="China, Hong Kong Special Administrative Region": return "Hong Kong, Special Administrative Region of China"
    elif country=="China, Macao Special Administrative Region": return "Macao, Special Administrative Region of China"
    elif country=="Congo": return "Congo (Brazzaville)"
    elif country=="Côte d'Ivoire": return u"Côte d'Ivoire"
    elif country=="Curaçao": return u"Curaçao"
    elif country=="Democratic People's Republic of Korea": return "Korea, Democratic People's Republic of"
    elif country=="Democratic Republic of the Congo": return "Congo, Democratic Republic of the"
    elif country=="Federated States of Micronesia": return "Micronesia, Federated States of"
    elif country=="Iran (Islamic Republic of)": return "Iran, Islamic Republic of"
    elif country=="Lao People's Democratic Republic": return "Lao PDR"
    elif country=="Libyan Arab Jamahiriya": return "Libya"
    elif country=="Republic of Korea": return "Korea, Republic of"
    elif country=="Republic of Moldova": return "Moldova"
    elif country=="Réunion": return u"Réunion"
    elif country=="Saint Vincent and the Grenadines": return "Saint Vincent and Grenadines"
    elif country=="Somalia ": return "Somalia"
    elif country=="State of Palestine": return "Palestinian Territory, Occupied"
    elif country=="Suriname": return u"Suriname *"
    elif country=="Syrian Arab Republic": return "Syrian Arab Republic (Syria)"
    elif country=="The former Yugoslav Republic of Macedonia": return "Macedonia, Republic of"
    elif country=="United Republic of Tanzania": return "Tanzania *, United Republic of"
    elif country=="United States Virgin Islands": return "Virgin Islands, US"
    elif country=="Yemen ": return "Yemen"
    else: return country

# %%
rnc={"Africa":"AFRI",
"Asia":"ASIA",
"Australia/New Zealand":"AUNZ",
"Caribbean":"CARR",
"Central America":"CTAM",
"Central Asia":"CTAS",
"Channel Islands":"CHIS",
"Curaçao":"CRCA",
"Eastern Africa":"ESAF",
"Eastern Asia":"ESAS",
"Eastern Europe":"ESEU",
"Europe":"EURO",
"Latin America and the Caribbean":"LACR",
"Least developed countries":"LEDC",
"Less developed regions":"LEDR",
"Less developed regions, excluding China":"LEDX",
"Less developed regions, excluding least developed countries":"LEDW",
"Melanesia":"MELA",
"Micronesia":"MICR",
"Middle Africa":"MDAF",
"More developed regions":"MORE",
"Northern Africa":"NOAF",
"Northern America":"NOAM",
"Northern Europe":"NOEU",
"Oceania":"OCEA",
"Other non-specified areas":"OTHR",
"Polynesia":"POLY",
"South America":"SOAM",
"South-Central Asia":"SCAS",
"South-Eastern Asia":"SEAS",
"Southern Africa":"SOAF",
"Southern Asia":"SOAS",
"Southern Europe":"SOEU",
"Sub-Saharan Africa":"SSAF",
"Western Africa":"WEAF",
"Western Asia":"WEAS",
"Western Europe":"WEEU",
"World":"WRLD"}

# %% [markdown]
# generate column country codes and replace country names with them

# %%
col=[]
for i in range(len(pop.columns)):
    try: 
        col.append(countries.loc[cnc(pop.columns[i])]['ISO3'])
    except: 
        #not a country, try region
        try: col.append(rnc[pop.columns[i]])
            #not a region, error
        except: col.append("ERROR")

# %% [markdown]
# upload to Quandl for all countries at once

# %%
pop.columns=col
qd.push(pop, "UNPD_POP_ALL", name = "UNPD Population ALL",\
        desc="ALL UNPD Historical Population and Predictions (http://esa.un.org/unpd/wpp/unpp/panel_population.htm)")

# %% [raw]
# http://www.quandl.com/CSALADENE/UNPD_POP_ALL

# %% [markdown]
# upload to Quandl country by country

# %%
for i in col:
    qd.push(pd.DataFrame(pop[i]), "UNPD_POP_"+i, name = "UNPD Population "+i,\
        desc=i+" UNPD Historical Population and Predictions (http://esa.un.org/unpd/wpp/unpp/panel_population.htm)")

# %% [markdown]
# all data uploaded on quandl. we can use regular query now to get it. but in the analysis it is easier to just use the csv file

# %%
qd.get("CSALADENE/UNPD_POP_HUN")
# Out:
# Using cached token h5ZMkUbTt3_6rJig3cfC for authentication.
# Returning Dataframe for
#  CSALADENE/UNPD_POP_HUN
#               HUN
# Year
# 1950-01-01   9338
# 1951-01-01   9478
# 1952-01-01   9595
# 1953-01-01   9691
# 1954-01-01   9768
# 1955-01-01   9829
# 1956-01-01   9877
# 1957-01-01   9914
# 1958-01-01   9945
# 1959-01-01   9973
# 1960-01-01  10001
# 1961-01-01  10031
# 1962-01-01  10065
# 1963-01-01  10100
# 1964-01-01  10136
# 1965-01-01  10170
# 1966-01-01  10205
# 1967-01-01  10239
# 1968-01-01  10274
# 1969-01-01  10309
# 1970-01-01  10346
# 1971-01-01  10382
# 1972-01-01  10417
# 1973-01-01  10455
# 1974-01-01  10495
# 1975-01-01  10541
# 1976-01-01  10594
# 1977-01-01  10651
# 1978-01-01  10704
# 1979-01-01  10743
# ...           ...
# 2071-01-01   8314
# 2072-01-01   8283
# 2073-01-01   8253
# 2074-01-01   8225
# 2075-01-01   8197
# 2076-01-01   8171
# 2077-01-01   8145
# 2078-01-01   8120
# 2079-01-01   8096
# 2080-01-01   8073
# 2081-01-01   8051
# 2082-01-01   8029
# 2083-01-01   8008
# 2084-01-01   7987
# 2085-01-01   7967
# 2086-01-01   7947
# 2087-01-01   7927
# 2088-01-01   7907
# 2089-01-01   7887
# 2090-01-01   7867
# 2091-01-01   7848
# 2092-01-01   7828
# 2093-01-01   7808
# 2094-01-01   7787
# 2095-01-01   7767
# 2096-01-01   7746
# 2097-01-01   7725
# 2098-01-01   7704
# 2099-01-01   7683
# 2100-01-01   7661
#
# [151 rows x 1 columns]
